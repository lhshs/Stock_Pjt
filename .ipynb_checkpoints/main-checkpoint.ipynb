# %%
import pandas as pd
import random
import os
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns
# from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Load Data

# %%
# main data

# Korea
kospi = pd.read_csv('./data/main_index/kospi(1990.01.02-2023.03.15).csv', sep='|', thousands = ',')
kospi = kospi[['Date','Close']]
kosdaq = pd.read_csv('./data/main_index/kosdaq(2001.01.02-2023.03.15).csv', sep='|', thousands = ',')
kosdaq = kosdaq[['Date','Close']]

# US
dow = pd.read_csv('./data/main_index/dow(2001.01.02-2023.03.15).csv', sep='|', thousands = ',')
dow = dow[['Date','Close']]
sp500 = pd.read_csv('./data/main_index/sp500(2001.01.02-2023.03.15).csv', sep='|', thousands = ',')
sp500 = sp500[['Date','Close']]
russel2000 = pd.read_csv('./data/main_index/russel2000(2001.01.03-2023.03.15).csv', sep='|', thousands = ',')
russel2000 = russel2000[['Date','Close']]
nasdaq = pd.read_csv('./data/main_index/nasdaq(2001.01.02-2023.03.15).csv', sep='|', thousands = ',')
nasdaq = nasdaq[['Date','Close']]
ftse = pd.read_csv('./data/main_index/FTSE(2004.03.05-2023.03.15).csv', sep='|', thousands = ',')
ftse = ftse[['Date','Close']]

# Japan
nikkie = pd.read_csv('./data/main_index/nikkie(2001.01.05-2023.03.15).csv', sep='|', thousands = ',')
nikkie = nikkie[['Date','Close']]

# China
ssec = pd.read_csv('./data/main_index/SSEC(1990.12.20-2023.03.15).csv', sep='|', thousands = ',')
ssec = ssec[['Date','Close']]
szse = pd.read_csv('./data/main_index/SZSE(1995.1.24-2023.03.15).csv', sep='|', thousands = ',')
szse = szse[['Date','Close']]
hsi = pd.read_csv('./data/main_index/hsi(2000.12.05-2023.03.15).csv', sep='|', thousands = ',')
hsi = hsi[['Date','Close']]

# %%
# bond_yield data

chi_bond_yield_1 = pd.read_csv('./data/bond_yield/china_1year_bond_yield(2002.06.04-2023.03.15).csv', sep='|', thousands = ',')
chi_bond_yield_1 = chi_bond_yield_1[['Date', 'Close']]
chi_bond_yield_3 = pd.read_csv('./data/bond_yield/china_3year_bond_yield(2000.09.22-2023.03.15).csv', sep='|', thousands = ',')
chi_bond_yield_3 = chi_bond_yield_3[['Date', 'Close']]
chi_bond_yield_5 = pd.read_csv('./data/bond_yield/china_5year_bond_yield(2001.03.14-2023.03.15).csv', sep='|', thousands = ',')
chi_bond_yield_5 = chi_bond_yield_5[['Date', 'Close']]
chi_bond_yield_10 = pd.read_csv('./data/bond_yield/china_10year_bond_yield(2002.06.06-2023.03.15).csv', sep='|', thousands = ',')
chi_bond_yield_10 = chi_bond_yield_10[['Date', 'Close']]

jap_bond_yield_1 = pd.read_csv('./data/bond_yield/japan_1year_bond_yield(2006.07.19-2023.03.15).csv', sep='|', thousands = ',')
jap_bond_yield_1 = jap_bond_yield_1[['Date', 'Close']]
jap_bond_yield_3 = pd.read_csv('./data/bond_yield/japan_3year_bond_yield(2006.07.19-2023.03.15).csv', sep='\t', thousands = ',')
jap_bond_yield_3 = jap_bond_yield_3[['Date', 'Close']]
jap_bond_yield_5 = pd.read_csv('./data/bond_yield/japan_5year_bond_yield(2006.07.27-2023.03.15).csv', sep='\t', thousands = ',')
jap_bond_yield_5 = jap_bond_yield_5[['Date', 'Close']]
jap_bond_yield_10 = pd.read_csv('./data/bond_yield/japan_10year_bond_yield(2006.07.19-2023.03.15).csv', sep='\t', thousands = ',')
jap_bond_yield_10 = jap_bond_yield_10[['Date', 'Close']]

kor_bond_yield_1 = pd.read_csv('./data/bond_yield/korea_1year_bond_yield(1995.05.03-2023.03.15).csv', sep='|', thousands = ',')
kor_bond_yield_1 = kor_bond_yield_1[['Date', 'Close']]
kor_bond_yield_3 = pd.read_csv('./data/bond_yield/korea_3year_bond_yield(1995.05.03-2023.03.15).csv', sep='|', thousands = ',')
kor_bond_yield_3 = kor_bond_yield_3[['Date', 'Close']]
kor_bond_yield_5 = pd.read_csv('./data/bond_yield/korea_5year_bond_yield(1995.05.03-2023.03.15).csv', sep='|', thousands = ',')
kor_bond_yield_5 = kor_bond_yield_5[['Date', 'Close']]
kor_bond_yield_10 = pd.read_csv('./data/bond_yield/korea_10year_bond_yield(2000.10.26-2023.03.15).csv', sep='|', thousands = ',')
kor_bond_yield_10 = kor_bond_yield_10[['Date', 'Close']]

us_bond_yield_1 = pd.read_csv('./data/bond_yield/us_1year_bond_yield(2008.06.05-2023.03.15).csv', sep='|', thousands = ',')
us_bond_yield_1 = us_bond_yield_1[['Date', 'Close']]
us_bond_yield_3 = pd.read_csv('./data/bond_yield/us_3year_bond_yield(1990.01.08-2023.03.15).csv', sep='|', thousands = ',')
us_bond_yield_3 = us_bond_yield_3[['Date', 'Close']]
us_bond_yield_5 = pd.read_csv('./data/bond_yield/us_5year_bond_yield(1990.01.08-2023.03.15).csv', sep='|', thousands = ',')
us_bond_yield_5 = us_bond_yield_5[['Date', 'Close']]
us_bond_yield_10 = pd.read_csv('./data/bond_yield/us_10year_bond_yield(1990.01.08-2023.03.15).csv', sep='|', thousands = ',')
us_bond_yield_10 = us_bond_yield_10[['Date', 'Close']]

# %%
# cpi data

chi_cpi_m = pd.read_csv('./data/cpi/china_cpi_compare_last_month(1996.01-2023.02).csv', sep='|', thousands = ',')
chi_cpi_y = pd.read_csv('./data/cpi/china_cpi_compare_last_year(1990.01-2023.02).csv', sep='|', thousands = ',')

jap_c_cpi_y = pd.read_csv('./data/cpi/japan_core_cpi_compare_last_year(1990.01-2023.02).csv', sep='|', thousands = ',')
jap_cpi_y = pd.read_csv('./data/cpi/japan_cpi_compare_last_year(1990.01-2023.02).csv', sep='|', thousands = ',')

kor_cpi_m = pd.read_csv('./data/cpi/korea_cpi_compare_last_month(1990.01-2023.02).csv', sep='|', thousands = ',')
kor_cpi_y = pd.read_csv('./data/cpi/korea_cpi_compare_last_year(1990.01-2023.02).csv', sep='|', thousands = ',')

us_c_cpi_m = pd.read_csv('./data/cpi/us_core_cpi_compare_last_month(1990.01-2023.02).csv', sep='|', thousands = ',')
us_c_cpi_y = pd.read_csv('./data/cpi/us_core_cpi_compare_last_year(1990.01-2023.02).csv', sep='|', thousands = ',')
us_cpi_m = pd.read_csv('./data/cpi/us_cpi_compare_last_month(1990.01-2023.02).csv', sep='|', thousands = ',')
us_cpi_y = pd.read_csv('./data/cpi/us_cpi_compare_last_year(1990.01-2023.02).csv', sep='|', thousands = ',')

# %%
# oil + dollar + gold + unemployment + usd_krw + vix

brent = pd.read_csv('./data/oil/brent(1990.01.02-2023.03.15).csv', sep='|', thousands = ',')
brent = brent[['Date', 'Close']]
dubai = pd.read_csv('./data/oil/dubai(2014.04.28-2023.03.15).csv', sep='|', thousands = ',')
dubai = dubai[['Date', 'Close']]
wti = pd.read_csv('./data/oil/wti(1990.01.02-2023.03.15).csv', sep='|', thousands = ',')
wti = wti[['Date', 'Close']]

bitcoin = pd.read_csv('./data/other/bitcoin(2010.07.18-2023.03.15).csv', sep='|', thousands = ',')
bitcoin = bitcoin[['Date', 'Close']]

dollar = pd.read_csv('./data/other/dollar_index(1990.01.01-2023.03.15).csv', sep='|', thousands = ',')
dollar = dollar[['Date', 'Close']]
gold = pd.read_csv('./data/other/gold_index(1990.01.02-2023.03.15).csv', sep='\t', thousands = ',')
gold = gold[['Date', 'Close']]

# kor_unem = pd.read_csv('./data/other/korea_unemployment_rate(2001.04-2023.02).csv', sep='|', thousands = ',')
# kor_unem = kor_unem[['Date', 'Change']]
# ja_unem = pd.read_csv('./data/other/japan_unemployment_rate(1999.09-2023.02)_날짜수정.csv', sep='|')
us_unem = pd.read_csv('./data/other/us_unemployment_rate(1994.10-2023.02).csv', sep='|', thousands = ',')
us_unem = us_unem[['Date', 'Change']]
kor_interest = pd.read_csv('./data/other/korea_interest_rate(1999.05-2023.02).csv', sep='|', thousands = ',')
kor_interest = kor_interest[['Date', 'Change']]

usd_krw = pd.read_csv('./data/other/USD_KRW(2009.03.25-2023.03.15).csv', sep='|', thousands = ',')
usd_krw = usd_krw[['Date', 'Close']]

vix = pd.read_csv('./data/other/vix(1990.01.03-2023.03.15).csv', sep='|', thousands = ',')
vix = vix[['Date', 'Close']]

# %% [markdown]
# ### Rename Columns

# %%
kospi.rename(columns = lambda x : 'kospi_' + x if x != 'Date' else x, inplace = True)
kosdaq.rename(columns = lambda x : 'kosdaq_' + x if x != 'Date' else x, inplace = True)
dow.rename(columns = lambda x : 'dow_' + x if x != 'Date' else x, inplace = True)
sp500.rename(columns = lambda x : 'sp500_' + x if x != 'Date' else x, inplace = True)
russel2000.rename(columns = lambda x : 'russel2000_' + x if x != 'Date' else x, inplace = True)
nasdaq.rename(columns = lambda x : 'nasdaq_' + x if x != 'Date' else x, inplace = True)
ftse.rename(columns = lambda x : 'ftse_' + x if x != 'Date' else x, inplace = True)
ftse.dropna(inplace=True)
nikkie.rename(columns = lambda x : 'nikkie_' + x if x != 'Date' else x, inplace = True)
nikkie.dropna(inplace=True)
ssec.rename(columns = lambda x : 'ssec_' + x if x != 'Date' else x, inplace = True)
szse.rename(columns = lambda x : 'szse_' + x if x != 'Date' else x, inplace = True)
hsi.rename(columns = lambda x : 'hsi_' + x if x != 'Date' else x, inplace = True)
hsi.dropna(inplace=True)

chi_bond_yield_1.rename(columns = lambda x : 'chi_bond_yield_1_' + x if x != 'Date' else x, inplace = True)
chi_bond_yield_3.rename(columns = lambda x : 'chi_bond_yield_3_' + x if x != 'Date' else x, inplace = True)
chi_bond_yield_5.rename(columns = lambda x : 'chi_bond_yield_5_' + x if x != 'Date' else x, inplace = True)
chi_bond_yield_10.rename(columns = lambda x : 'chi_bond_yield_10_' + x if x != 'Date' else x, inplace = True)
chi_bond_yield_10.dropna(inplace=True)

jap_bond_yield_1.rename(columns = lambda x : 'jap_bond_yield_1_' + x if x != 'Date' else x, inplace = True)
jap_bond_yield_3.rename(columns = lambda x : 'jap_bond_yield_3_' + x if x != 'Date' else x, inplace = True)
jap_bond_yield_5.rename(columns = lambda x : 'jap_bond_yield_5_' + x if x != 'Date' else x, inplace = True)
jap_bond_yield_10.rename(columns = lambda x : 'jap_bond_yield_10_' + x if x != 'Date' else x, inplace = True)

kor_bond_yield_1.rename(columns = lambda x : 'kor_bond_yield_1_' + x if x != 'Date' else x, inplace = True)
kor_bond_yield_3.rename(columns = lambda x : 'kor_bond_yield_3_' + x if x != 'Date' else x, inplace = True)
kor_bond_yield_5.rename(columns = lambda x : 'kor_bond_yield_5_' + x if x != 'Date' else x, inplace = True)
kor_bond_yield_10.rename(columns = lambda x : 'kor_bond_yield_10_' + x if x != 'Date' else x, inplace = True)

us_bond_yield_1.rename(columns = lambda x : 'us_bond_yield_1_' + x if x != 'Date' else x, inplace = True)
us_bond_yield_3.rename(columns = lambda x : 'us_bond_yield_3_' + x if x != 'Date' else x, inplace = True)
us_bond_yield_5.rename(columns = lambda x : 'us_bond_yield_5_' + x if x != 'Date' else x, inplace = True)
us_bond_yield_5.dropna(inplace=True)
us_bond_yield_10.rename(columns = lambda x : 'us_bond_yield_10_' + x if x != 'Date' else x, inplace = True)

chi_cpi_m.rename(columns = lambda x : 'chi_cpi_m_' + x if x != 'Date' else x, inplace = True)
chi_cpi_y.rename(columns = lambda x : 'chi_cpi_y_' + x if x != 'Date' else x, inplace = True)
jap_c_cpi_y.rename(columns = lambda x : 'jap_c_cpi_y_' + x if x != 'Date' else x, inplace = True)
jap_cpi_y.rename(columns = lambda x : 'jap_cpi_y_' + x if x != 'Date' else x, inplace = True)
kor_cpi_m.rename(columns = lambda x : 'kor_cpi_m_' + x if x != 'Date' else x, inplace = True)
kor_cpi_y.rename(columns = lambda x : 'kor_cpi_y_' + x if x != 'Date' else x, inplace = True)
us_c_cpi_m.rename(columns = lambda x : 'us_c_cpi_m_' + x if x != 'Date' else x, inplace = True)
us_c_cpi_y.rename(columns = lambda x : 'us_c_cpi_y_' + x if x != 'Date' else x, inplace = True)
us_cpi_m.rename(columns = lambda x : 'us_cpi_m_' + x if x != 'Date' else x, inplace = True)
us_cpi_y.rename(columns = lambda x : 'us_cpi_y_' + x if x != 'Date' else x, inplace = True)

brent.rename(columns = lambda x : 'brent_' + x if x != 'Date' else x, inplace = True)
dubai.rename(columns = lambda x : 'dubai_' + x if x != 'Date' else x, inplace = True)
wti.rename(columns = lambda x : 'wti_' + x if x != 'Date' else x, inplace = True)

bitcoin.rename(columns = lambda x : 'bitcoin_' + x if x != 'Date' else x, inplace = True)
dollar.rename(columns = lambda x : 'dollar_' + x if x != 'Date' else x, inplace = True)
gold.rename(columns = lambda x : 'gold_' + x if x != 'Date' else x, inplace = True)
# kor_unem.rename(columns = lambda x : 'kor_unem_' + x if x != 'Date' else x, inplace = True)
us_unem.rename(columns = lambda x : 'us_unem_' + x if x != 'Date' else x, inplace = True)
kor_interest.rename(columns = lambda x : 'kor_interest_' + x if x != 'Date' else x, inplace = True)
usd_krw.rename(columns = lambda x : 'usd_krw_' + x if x != 'Date' else x, inplace = True)
vix.rename(columns = lambda x : 'vix_' + x if x != 'Date' else x, inplace = True)

# %%
variables = [kospi, kosdaq, dow, sp500, russel2000, nasdaq, ftse, nikkie, ssec, szse, hsi, 
             chi_bond_yield_1, chi_bond_yield_3, chi_bond_yield_5, chi_bond_yield_10,
             jap_bond_yield_1, jap_bond_yield_3, jap_bond_yield_5, jap_bond_yield_10,
             kor_bond_yield_1, kor_bond_yield_3, kor_bond_yield_5, kor_bond_yield_10,
             us_bond_yield_1, us_bond_yield_3, us_bond_yield_5, us_bond_yield_10,
             chi_cpi_m, chi_cpi_y, jap_c_cpi_y, jap_cpi_y, kor_cpi_m, kor_cpi_y, 
             us_c_cpi_m, us_c_cpi_y, us_cpi_m, us_cpi_y, brent, dubai, wti, bitcoin,
             dollar, gold, us_unem, usd_krw, vix]

# %%
for i in variables:
    print(i)

# %%
kosdaq
# Out:
#             Date  kosdaq_Close
# 0     2001-01-02        557.00
# 1     2001-01-03        569.00
# 2     2001-01-04        615.10
# 3     2001-01-05        625.20
# 4     2001-01-08        650.00
# ...          ...           ...
# 5484  2023-03-09        809.22
# 5485  2023-03-10        788.60
# 5486  2023-03-13        788.89
# 5487  2023-03-14        758.05
# 5488  2023-03-15        781.17
#
# [5489 rows x 2 columns]

# %% [markdown]
# ### 단변량 시계열 기준으로 kospi 값과 상관관계가 높은 feature들을 Auto ARIMA로 학습 및 예측

# %%
from sklearn.preprocessing import MinMaxScaler

minmax_scaler = MinMaxScaler()

# %%
a = '형석'
'안녕{a}'.format(a=a)
# Out:
# '안녕형석'

# %%
# KOSPI와 각 FEATURE간 상관관계 도출 및 그래프 그리기

def get_corr(lst):
    for i in lst:
        if str(i) != str(kospi):
            global 
            oneone = pd.merge(kospi, i, how = 'right', left_on = 'Date', right_on = 'Date')
            oneone = oneone.set_index('Date')
            oneone.fillna(method = 'bfill', inplace = True) 
            minmax_scaled = minmax_scaler.fit_transform(oneone.values)
            f'df_{i.columns[1]}' = pd.DataFrame(data = minmax_scaled, columns = oneone.columns, index = oneone.index)
#             print(df)
#             print(df.corr())
        
            df.plot(figsize=(10,5))
            plt.title(f'kospi_{i.columns[1]}')
            plt.show()
            print('🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟')
            print('')
            print('')
# Out:
#   Input In [56]
#     global 'df_{i.columns[1]}'.format(i=i)
#            ^
# SyntaxError: invalid syntax

# %%
get_corr(variables)
# Out:
#             kospi_Close  kosdaq_Close
# Date
# 2001-01-02     0.018400      0.370313
# 2001-01-03     0.018569      0.385336
# 2001-01-04     0.031469      0.443047
# 2001-01-05     0.039518      0.455690
# 2001-01-08     0.041563      0.486737
# ...                 ...           ...
# 2023-03-09     0.687595      0.686058
# 2023-03-10     0.678958      0.660245
# 2023-03-13     0.684602      0.660608
# 2023-03-14     0.662874      0.622000
# 2023-03-15     0.673715      0.650943
#
# [5489 rows x 2 columns]
#               kospi_Close  kosdaq_Close
# kospi_Close       1.00000       0.60456
# kosdaq_Close      0.60456       1.00000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  dow_Close
# Date
# 1990-01-02     0.207784   0.012925
# 1990-01-03     0.207784   0.012912
# 1990-01-04     0.214471   0.012516
# 1990-01-05     0.209939   0.011853
# 1990-01-08     0.211377   0.012466
# ...                 ...        ...
# 2023-03-09     0.707088   0.868051
# 2023-03-10     0.698989   0.858000
# 2023-03-13     0.704282   0.855360
# 2023-03-14     0.683910   0.865084
# 2023-03-15     0.694074   0.857021
#
# [8365 rows x 2 columns]
#              kospi_Close  dow_Close
# kospi_Close     1.000000   0.865106
# dow_Close       0.865106   1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  sp500_Close
# Date
# 1990-01-02     0.207784     0.014263
# 1990-01-03     0.207784     0.014063
# 1990-01-04     0.214471     0.013375
# 1990-01-05     0.209939     0.012597
# 1990-01-08     0.211377     0.012953
# ...                 ...          ...
# 2023-03-09     0.707088     0.804882
# 2023-03-10     0.698989     0.792278
# 2023-03-13     0.704282     0.790983
# 2023-03-14     0.683910     0.805379
# 2023-03-15     0.694074     0.799018
#
# [8365 rows x 2 columns]
#              kospi_Close  sp500_Close
# kospi_Close     1.000000     0.840515
# sp500_Close     0.840515     1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  russel2000_Close
# Date
# 2001-01-03     0.018569          0.074373
# 2001-01-04     0.031469          0.070974
# 2001-01-05     0.039518          0.064329
# 2001-01-08     0.041563          0.063620
# 2001-01-09     0.042715          0.064711
# ...                 ...               ...
# 2023-03-09     0.687595          0.708773
# 2023-03-10     0.678958          0.683301
# 2023-03-13     0.684602          0.669878
# 2023-03-14     0.662874          0.685281
# 2023-03-15     0.673715          0.670653
#
# [5598 rows x 2 columns]
#                   kospi_Close  russel2000_Close
# kospi_Close          1.000000          0.885861
# russel2000_Close     0.885861          1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  nasdaq_Close
# Date
# 1990-01-02     0.207784      0.008511
# 1990-01-03     0.207784      0.008610
# 1990-01-04     0.214471      0.008514
# 1990-01-05     0.209939      0.008440
# 1990-01-08     0.211377      0.008471
# ...                 ...           ...
# 2023-03-09     0.707088      0.700033
# 2023-03-10     0.698989      0.687354
# 2023-03-13     0.704282      0.690529
# 2023-03-14     0.683910      0.705741
# 2023-03-15     0.694074      0.706116
#
# [8365 rows x 2 columns]
#               kospi_Close  nasdaq_Close
# kospi_Close      1.000000      0.819718
# nasdaq_Close     0.819718      1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  ftse_Close
# Date
# 2004-03-05     0.071855    0.103122
# 2004-03-08     0.069813    0.099659
# 2004-03-09     0.066518    0.101293
# 2004-03-10     0.060500    0.108347
# 2004-03-11     0.058145    0.109960
# ...                 ...         ...
# 2023-03-09     0.657289    0.482762
# 2023-03-10     0.647814    0.475054
# 2023-03-13     0.654006    0.480807
# 2023-03-14     0.630170    0.476570
# 2023-03-15     0.642063    0.476694
#
# [4667 rows x 2 columns]
#              kospi_Close  ftse_Close
# kospi_Close     1.000000    0.712326
# ftse_Close      0.712326    1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  nikkie_Close
# Date
# 2001-01-05     0.039518      0.288486
# 2001-01-09     0.042715      0.277599
# 2001-01-10     0.032453      0.270067
# 2001-01-11     0.032798      0.260261
# 2001-01-12     0.041993      0.266472
# ...                 ...           ...
# 2023-03-09     0.687595      0.913320
# 2023-03-10     0.678958      0.893029
# 2023-03-13     0.684602      0.879859
# 2023-03-14     0.662874      0.853989
# 2023-03-15     0.673715      0.854304
#
# [5463 rows x 2 columns]
#               kospi_Close  nikkie_Close
# kospi_Close      1.000000      0.751697
# nikkie_Close     0.751697      1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  ssec_Close
# Date
# 1990-12-20     0.138185    0.000000
# 1990-12-21     0.141557    0.000792
# 1990-12-24     0.136771    0.001697
# 1990-12-25     0.137547    0.002649
# 1990-12-26     0.137547    0.003487
# ...                 ...         ...
# 2023-03-09     0.707088    0.529705
# 2023-03-10     0.698989    0.522021
# 2023-03-13     0.704282    0.528471
# 2023-03-14     0.683910    0.524565
# 2023-03-15     0.694074    0.527571
#
# [7874 rows x 2 columns]
#              kospi_Close  ssec_Close
# kospi_Close     1.000000    0.794849
# ssec_Close      0.794849    1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  szse_Close
# Date
# 1995-01-24     0.210508    0.011909
# 1995-01-25     0.210514    0.012685
# 1995-01-26     0.214150    0.012182
# 1995-01-27     0.207275    0.012618
# 1995-02-13     0.223819    0.012270
# ...                 ...         ...
# 2023-03-09     0.707088    0.572543
# 2023-03-10     0.698989    0.565154
# 2023-03-13     0.704282    0.568513
# 2023-03-14     0.683910    0.563758
# 2023-03-15     0.694074    0.563589
#
# [6827 rows x 2 columns]
#              kospi_Close  szse_Close
# kospi_Close     1.000000    0.837091
# szse_Close      0.837091    1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  hsi_Close
# Date
# 2000-12-05     0.016993   0.249108
# 2000-12-06     0.017321   0.270354
# 2000-12-07     0.019397   0.266821
# 2000-12-08     0.023286   0.274006
# 2000-12-11     0.030334   0.282865
# ...                 ...        ...
# 2023-03-09     0.687595   0.465414
# 2023-03-10     0.678958   0.440932
# 2023-03-13     0.684602   0.456129
# 2023-03-14     0.662874   0.438024
# 2023-03-15     0.673715   0.449821
#
# [5519 rows x 2 columns]
#              kospi_Close  hsi_Close
# kospi_Close     1.000000   0.875537
# hsi_Close       0.875537   1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  chi_bond_yield_1_Close
# Date
# 2002-06-04     0.104334                0.386269
# 2002-06-05     0.105503                0.387463
# 2002-06-06     0.100331                0.304776
# 2002-06-07     0.100331                0.302388
# 2002-06-10     0.106331                0.314925
# ...                 ...                     ...
# 2023-03-09     0.682391                0.402985
# 2023-03-10     0.673609                0.398507
# 2023-03-13     0.679348                0.398209
# 2023-03-14     0.657258                0.401194
# 2023-03-15     0.668280                0.404478
#
# [5211 rows x 2 columns]
#                         kospi_Close  chi_bond_yield_1_Close
# kospi_Close                1.000000                0.251033
# chi_bond_yield_1_Close     0.251033                1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  chi_bond_yield_3_Close
# Date
# 2000-09-22     0.018773                0.384513
# 2000-09-25     0.029961                0.368363
# 2000-09-26     0.031020                0.399779
# 2000-09-27     0.035196                0.379204
# 2000-09-29     0.040155                0.379204
# ...                 ...                     ...
# 2023-03-09     0.684049                0.561504
# 2023-03-10     0.675313                0.560841
# 2023-03-13     0.681022                0.562611
# 2023-03-14     0.659047                0.563938
# 2023-03-15     0.670011                0.559735
#
# [4570 rows x 2 columns]
#                         kospi_Close  chi_bond_yield_3_Close
# kospi_Close                1.000000                0.247441
# chi_bond_yield_3_Close     0.247441                1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  chi_bond_yield_5_Close
# Date
# 2001-03-14     0.026272                0.129798
# 2001-03-15     0.025761                0.129881
# 2001-03-19     0.023117                0.130211
# 2001-03-20     0.022151                0.130334
# 2001-03-22     0.020550                0.130499
# ...                 ...                     ...
# 2023-03-09     0.687595                0.111533
# 2023-03-10     0.678958                0.111120
# 2023-03-13     0.684602                0.111409
# 2023-03-14     0.662874                0.111409
# 2023-03-15     0.673715                0.111244
#
# [4553 rows x 2 columns]
#                         kospi_Close  chi_bond_yield_5_Close
# kospi_Close                1.000000                0.093738
# chi_bond_yield_5_Close     0.093738                1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  chi_bond_yield_10_Close
# Date
# 2002-06-06     0.100331                 0.000000
# 2002-06-07     0.100331                 0.001577
# 2002-06-10     0.106331                 0.008277
# 2002-06-11     0.107560                 0.007095
# 2002-06-12     0.110331                 0.006307
# ...                 ...                      ...
# 2023-03-09     0.682391                 0.186835
# 2023-03-10     0.673609                 0.183682
# 2023-03-13     0.679348                 0.184864
# 2023-03-14     0.657258                 0.185652
# 2023-03-15     0.668280                 0.182893
#
# [5309 rows x 2 columns]
#                          kospi_Close  chi_bond_yield_10_Close
# kospi_Close                 1.000000                -0.175386
# chi_bond_yield_10_Close    -0.175386                 1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  jap_bond_yield_1_Close
# Date
# 2006-07-19     0.124617                0.009646
# 2006-07-20     0.141372                0.009596
# 2006-07-21     0.140539                0.009596
# 2006-07-24     0.137167                0.009696
# 2006-07-25     0.144106                0.009746
# ...                 ...                     ...
# 2023-03-10     0.615197                0.002668
# 2023-03-12     0.621963                0.002728
# 2023-03-13     0.621963                0.002548
# 2023-03-14     0.595920                0.002528
# 2023-03-15     0.608914                0.002270
#
# [4577 rows x 2 columns]
#                         kospi_Close  jap_bond_yield_1_Close
# kospi_Close                1.000000               -0.108442
# jap_bond_yield_1_Close    -0.108442                1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  jap_bond_yield_3_Close
# Date
# 2006-07-19     0.124617                0.841463
# 2006-07-20     0.141372                0.832317
# 2006-07-21     0.140539                0.832317
# 2006-07-24     0.137167                0.850610
# 2006-07-25     0.144106                0.865244
# ...                 ...                     ...
# 2023-03-10     0.615197                0.217073
# 2023-03-12     0.621963                0.230488
# 2023-03-13     0.621963                0.223171
# 2023-03-14     0.595920                0.201829
# 2023-03-15     0.608914                0.212805
#
# [4568 rows x 2 columns]
#                         kospi_Close  jap_bond_yield_3_Close
# kospi_Close                 1.00000                -0.62453
# jap_bond_yield_3_Close     -0.62453                 1.00000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  jap_bond_yield_5_Close
# Date
# 2006-07-27     0.151078                0.902932
# 2006-07-28     0.151416                0.920121
# 2006-07-31     0.151733                0.920121
# 2006-08-01     0.147313                0.922649
# 2006-08-02     0.150588                0.905460
# ...                 ...                     ...
# 2023-03-10     0.615197                0.292214
# 2023-03-12     0.621963                0.283620
# 2023-03-13     0.621963                0.279575
# 2023-03-14     0.595920                0.254803
# 2023-03-15     0.608914                0.258847
#
# [4569 rows x 2 columns]
#                         kospi_Close  jap_bond_yield_5_Close
# kospi_Close                1.000000               -0.639599
# jap_bond_yield_5_Close    -0.639599                1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  jap_bond_yield_10_Close
# Date
# 2006-02-07     0.166295                 0.820009
# 2006-02-08     0.157298                 0.815640
# 2006-02-09     0.161807                 0.811708
# 2006-02-10     0.167541                 0.827872
# 2006-02-13     0.161439                 0.811708
# ...                 ...                      ...
# 2023-03-10     0.615197                 0.298384
# 2023-03-12     0.621963                 0.288772
# 2023-03-13     0.621963                 0.262997
# 2023-03-14     0.595920                 0.247706
# 2023-03-15     0.608914                 0.268239
#
# [4604 rows x 2 columns]
#                          kospi_Close  jap_bond_yield_10_Close
# kospi_Close                 1.000000                -0.706936
# jap_bond_yield_10_Close    -0.706936                 1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  kor_bond_yield_1_Close
# Date
# 1995-05-03     0.211797                0.782258
# 1995-05-04     0.212233                0.782258
# 1995-05-06     0.211047                0.779570
# 1995-05-08     0.208379                0.779570
# 1995-05-09     0.205939                0.779570
# ...                 ...                     ...
# 2023-03-11     0.704282                0.194892
# 2023-03-12     0.704282                0.194892
# 2023-03-13     0.704282                0.190914
# 2023-03-14     0.683910                0.183763
# 2023-03-15     0.694074                0.183602
#
# [7126 rows x 2 columns]
#                         kospi_Close  kor_bond_yield_1_Close
# kospi_Close                1.000000               -0.764586
# kor_bond_yield_1_Close    -0.764586                1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  kor_bond_yield_3_Close
# Date
# 1995-05-03     0.211797                0.842857
# 1995-05-04     0.212233                0.842857
# 1995-05-06     0.211047                0.840000
# 1995-05-08     0.208379                0.840000
# 1995-05-09     0.205939                0.840000
# ...                 ...                     ...
# 2023-03-11     0.704282                0.212114
# 2023-03-12     0.704282                0.212114
# 2023-03-13     0.704282                0.196114
# 2023-03-14     0.683910                0.191486
# 2023-03-15     0.694074                0.198629
#
# [8087 rows x 2 columns]
#                         kospi_Close  kor_bond_yield_3_Close
# kospi_Close                1.000000               -0.742747
# kor_bond_yield_3_Close    -0.742747                1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  kor_bond_yield_5_Close
# Date
# 1995-05-03     0.211797                0.835294
# 1995-05-04     0.212233                0.835294
# 1995-05-06     0.211047                0.835294
# 1995-05-08     0.208379                0.835294
# 1995-05-09     0.205939                0.835294
# ...                 ...                     ...
# 2023-03-11     0.704282                0.212353
# 2023-03-12     0.704282                0.212353
# 2023-03-13     0.704282                0.199647
# 2023-03-14     0.683910                0.195294
# 2023-03-15     0.694074                0.201412
#
# [8041 rows x 2 columns]
#                         kospi_Close  kor_bond_yield_5_Close
# kospi_Close                1.000000               -0.761104
# kor_bond_yield_5_Close    -0.761104                1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  kor_bond_yield_10_Close
# Date
# 2000-10-26     0.019359                 1.000000
# 2000-10-27     0.016422                 0.992771
# 2000-10-28     0.012681                 0.992771
# 2000-10-30     0.012681                 0.990361
# 2000-11-01     0.028204                 0.981928
# ...                 ...                      ...
# 2023-03-11     0.684602                 0.431566
# 2023-03-12     0.684602                 0.431566
# 2023-03-13     0.684602                 0.409398
# 2023-03-14     0.662874                 0.397952
# 2023-03-15     0.673715                 0.411807
#
# [6016 rows x 2 columns]
#                          kospi_Close  kor_bond_yield_10_Close
# kospi_Close                 1.000000                -0.723634
# kor_bond_yield_10_Close    -0.723634                 1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  us_bond_yield_1_Close
# Date
# 2008-06-05     0.377594               0.399462
# 2008-06-06     0.367726               0.391580
# 2008-06-09     0.367726               0.432141
# 2008-06-10     0.353114               0.471742
# 2008-06-11     0.356194               0.458862
# ...                 ...                    ...
# 2023-03-09     0.625550               0.988274
# 2023-03-10     0.615197               0.929450
# 2023-03-13     0.621963               0.817186
# 2023-03-14     0.595920               0.852364
# 2023-03-15     0.608914               0.814494
#
# [3883 rows x 2 columns]
#                        kospi_Close  us_bond_yield_1_Close
# kospi_Close               1.000000               0.162912
# us_bond_yield_1_Close     0.162912               1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  us_bond_yield_3_Close
# Date
# 1990-01-08     0.211377               0.871057
# 1990-01-09     0.211625               0.870389
# 1990-01-10     0.208739               0.869721
# 1990-01-11     0.206025               0.875288
# 1990-01-12     0.205972               0.876068
# ...                 ...                    ...
# 2023-03-09     0.707088               0.493803
# 2023-03-10     0.698989               0.468850
# 2023-03-13     0.704282               0.420112
# 2023-03-14     0.683910               0.443774
# 2023-03-15     0.694074               0.409946
#
# [7172 rows x 2 columns]
#                        kospi_Close  us_bond_yield_3_Close
# kospi_Close               1.000000              -0.722529
# us_bond_yield_3_Close    -0.722529               1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  us_bond_yield_5_Close
# Date
# 1990-01-08     0.211377               0.868968
# 1990-01-09     0.211625               0.869418
# 1990-01-10     0.208739               0.868968
# 1990-01-11     0.206025               0.874484
# 1990-01-12     0.205972               0.877973
# ...                 ...                    ...
# 2023-03-09     0.707088               0.450035
# 2023-03-10     0.698989               0.425326
# 2023-03-13     0.704282               0.392883
# 2023-03-14     0.683910               0.411570
# 2023-03-15     0.694074               0.379499
#
# [8614 rows x 2 columns]
#                        kospi_Close  us_bond_yield_5_Close
# kospi_Close               1.000000              -0.742034
# us_bond_yield_5_Close    -0.742034               1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  us_bond_yield_10_Close
# Date
# 1990-01-08     0.211377                0.880411
# 1990-01-09     0.211625                0.879840
# 1990-01-10     0.208739                0.879840
# 1990-01-11     0.206025                0.883609
# 1990-01-12     0.205972                0.889549
# ...                 ...                     ...
# 2023-03-09     0.707088                0.408452
# 2023-03-10     0.698989                0.383324
# 2023-03-13     0.704282                0.354083
# 2023-03-14     0.683910                0.359338
# 2023-03-15     0.694074                0.350657
#
# [8515 rows x 2 columns]
#                         kospi_Close  us_bond_yield_10_Close
# kospi_Close                1.000000               -0.797133
# us_bond_yield_10_Close    -0.797133                1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  chi_cpi_m_Change
# Date
# 1996-01-01     0.194694          0.886364
# 1996-02-01     0.194694          0.931818
# 1996-03-01     0.192456          0.545455
# 1996-04-01     0.192456          0.568182
# 1996-05-01     0.202371          0.295455
# ...                 ...               ...
# 2022-10-01     0.681886          0.431818
# 2022-11-01     0.681886          0.363636
# 2022-12-01     0.730475          0.409091
# 2023-01-01     0.720382          0.590909
# 2023-02-01     0.720382          0.295455
#
# [326 rows x 2 columns]
#                   kospi_Close  chi_cpi_m_Change
# kospi_Close          1.000000          0.085931
# chi_cpi_m_Change     0.085931          1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  chi_cpi_y_Change
# Date
# 1990-01-01     0.194929          0.217391
# 1990-02-01     0.194929          0.220736
# 1990-03-01     0.138693          0.187291
# 1990-04-01     0.138693          0.180602
# 1990-05-01     0.138693          0.163880
# ...                 ...               ...
# 2022-10-01     0.681886          0.143813
# 2022-11-01     0.681886          0.127090
# 2022-12-01     0.730475          0.133779
# 2023-01-01     0.720382          0.143813
# 2023-02-01     0.720382          0.107023
#
# [398 rows x 2 columns]
#                   kospi_Close  chi_cpi_y_Change
# kospi_Close          1.000000         -0.175752
# chi_cpi_y_Change    -0.175752          1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  jap_c_cpi_y_Change
# Date
# 1990-01-01     0.194929            0.815385
# 1990-02-01     0.194929            0.815385
# 1990-03-01     0.138693            0.830769
# 1990-04-01     0.138693            0.676923
# 1990-05-01     0.138693            0.676923
# ...                 ...                 ...
# 2022-10-01     0.681886            0.907692
# 2022-11-01     0.681886            0.923077
# 2022-12-01     0.730475            0.969231
# 2023-01-01     0.720382            1.000000
# 2023-02-01     0.720382            0.830769
#
# [397 rows x 2 columns]
#                     kospi_Close  jap_c_cpi_y_Change
# kospi_Close            1.000000           -0.017854
# jap_c_cpi_y_Change    -0.017854            1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  jap_cpi_y_Change
# Date
# 1990-01-01     0.194929          0.808824
# 1990-02-01     0.194929          0.897059
# 1990-03-01     0.138693          0.882353
# 1990-04-01     0.138693          0.735294
# 1990-05-01     0.138693          0.764706
# ...                 ...               ...
# 2022-10-01     0.681886          0.911765
# 2022-11-01     0.681886          0.926471
# 2022-12-01     0.730475          0.955882
# 2023-01-01     0.720382          1.000000
# 2023-02-01     0.720382          0.852941
#
# [398 rows x 2 columns]
#                   kospi_Close  jap_cpi_y_Change
# kospi_Close          1.000000         -0.012534
# jap_cpi_y_Change    -0.012534          1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  kor_cpi_m_Change
# Date
# 1990-01-01     0.194929           0.93750
# 1990-02-01     0.194929           0.40625
# 1990-03-01     0.138693           0.53125
# 1990-04-01     0.138693           0.56250
# 1990-05-01     0.138693           0.56250
# ...                 ...               ...
# 2022-10-01     0.681886           0.31250
# 2022-11-01     0.681886           0.28125
# 2022-12-01     0.730475           0.18750
# 2023-01-01     0.720382           0.46875
# 2023-02-01     0.720382           0.31250
#
# [396 rows x 2 columns]
#                   kospi_Close  kor_cpi_m_Change
# kospi_Close          1.000000         -0.162475
# kor_cpi_m_Change    -0.162475          1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  kor_cpi_y_Change
# Date
# 1990-01-01     0.194929          0.733333
# 1990-02-01     0.194929          0.761905
# 1990-03-01     0.138693          0.800000
# 1990-04-01     0.138693          0.866667
# 1990-05-01     0.138693          0.857143
# ...                 ...               ...
# 2022-10-01     0.681886          0.580952
# 2022-11-01     0.681886          0.514286
# 2022-12-01     0.730475          0.514286
# 2023-01-01     0.720382          0.533333
# 2023-02-01     0.720382          0.495238
#
# [398 rows x 2 columns]
#                   kospi_Close  kor_cpi_y_Change
# kospi_Close          1.000000         -0.528654
# kor_cpi_y_Change    -0.528654          1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  us_c_cpi_m_Change
# Date
# 1990-01-01     0.194929           0.615385
# 1990-02-01     0.194929           0.692308
# 1990-03-01     0.138693           0.769231
# 1990-04-01     0.138693           0.615385
# 1990-05-01     0.138693           0.538462
# ...                 ...                ...
# 2022-10-01     0.681886           0.538462
# 2022-11-01     0.681886           0.461538
# 2022-12-01     0.730475           0.538462
# 2023-01-01     0.720382           0.615385
# 2023-02-01     0.720382           0.692308
#
# [398 rows x 2 columns]
#                    kospi_Close  us_c_cpi_m_Change
# kospi_Close           1.000000           0.055568
# us_c_cpi_m_Change     0.055568           1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  us_c_cpi_y_Change
# Date
# 1990-01-01     0.194929           0.633333
# 1990-02-01     0.194929           0.666667
# 1990-03-01     0.138693           0.716667
# 1990-04-01     0.138693           0.700000
# 1990-05-01     0.138693           0.700000
# ...                 ...                ...
# 2022-10-01     0.681886           0.950000
# 2022-11-01     0.681886           0.900000
# 2022-12-01     0.730475           0.850000
# 2023-01-01     0.720382           0.833333
# 2023-02-01     0.720382           0.816667
#
# [398 rows x 2 columns]
#                    kospi_Close  us_c_cpi_y_Change
# kospi_Close           1.000000          -0.072284
# us_c_cpi_y_Change    -0.072284           1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  us_cpi_m_Change
# Date
# 1990-01-01     0.194929         0.846154
# 1990-02-01     0.194929         0.615385
# 1990-03-01     0.138693         0.653846
# 1990-04-01     0.138693         0.538462
# 1990-05-01     0.138693         0.538462
# ...                 ...              ...
# 2022-10-01     0.681886         0.615385
# 2022-11-01     0.681886         0.500000
# 2022-12-01     0.730475         0.423077
# 2023-01-01     0.720382         0.653846
# 2023-02-01     0.720382         0.615385
#
# [398 rows x 2 columns]
#                  kospi_Close  us_cpi_m_Change
# kospi_Close         1.000000         0.099548
# us_cpi_m_Change     0.099548         1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  us_cpi_y_Change
# Date
# 1990-01-01     0.194929         0.651786
# 1990-02-01     0.194929         0.660714
# 1990-03-01     0.138693         0.651786
# 1990-04-01     0.138693         0.607143
# 1990-05-01     0.138693         0.580357
# ...                 ...              ...
# 2022-10-01     0.681886         0.875000
# 2022-11-01     0.681886         0.821429
# 2022-12-01     0.730475         0.767857
# 2023-01-01     0.720382         0.758929
# 2023-02-01     0.720382         0.723214
#
# [398 rows x 2 columns]
#                  kospi_Close  us_cpi_y_Change
# kospi_Close         1.000000         0.050352
# us_cpi_y_Change     0.050352         1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  brent_Close
# Date
# 1990-01-02     0.207784     0.079669
# 1990-01-03     0.207784     0.088317
# 1990-01-04     0.214471     0.086998
# 1990-01-05     0.209939     0.090589
# 1990-01-08     0.211377     0.079742
# ...                 ...          ...
# 2023-03-09     0.707088     0.527338
# 2023-03-10     0.698989     0.536060
# 2023-03-13     0.704282     0.521328
# 2023-03-14     0.683910     0.496995
# 2023-03-15     0.694074     0.466432
#
# [8486 rows x 2 columns]
#              kospi_Close  brent_Close
# kospi_Close     1.000000     0.732981
# brent_Close     0.732981     1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  dubai_Close
# Date
# 2014-04-28     0.276915     0.820897
# 2014-04-29     0.274485     0.820897
# 2014-04-30     0.272872     0.820897
# 2014-05-01     0.271600     0.820897
# 2014-05-02     0.271600     0.820897
# ...                 ...          ...
# 2023-03-09     0.520386     0.600909
# 2023-03-10     0.507126     0.609801
# 2023-03-13     0.515791     0.598685
# 2023-03-14     0.482434     0.581191
# 2023-03-15     0.499077     0.562343
#
# [2233 rows x 2 columns]
#              kospi_Close  dubai_Close
# kospi_Close     1.000000     0.318676
# dubai_Close     0.318676     1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  wti_Close
# Date
# 1990-01-02     0.207784   0.330855
# 1990-01-03     0.207784   0.335174
# 1990-01-04     0.214471   0.333698
# 1990-01-05     0.209939   0.331894
# 1990-01-08     0.211377   0.323912
# ...                 ...        ...
# 2023-03-09     0.707088   0.619670
# 2023-03-10     0.698989   0.624918
# 2023-03-13     0.704282   0.614640
# 2023-03-14     0.683910   0.595670
# 2023-03-15     0.694074   0.575333
#
# [8457 rows x 2 columns]
#              kospi_Close  wti_Close
# kospi_Close     1.000000   0.710346
# wti_Close       0.710346   1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  bitcoin_Close
# Date
# 2010-07-18     0.148471       0.000000
# 2010-07-19     0.148471       0.000000
# 2010-07-20     0.151080       0.000000
# 2010-07-21     0.157580       0.000000
# 2010-07-22     0.150408       0.000000
# ...                 ...            ...
# 2023-03-11     0.515791       0.303096
# 2023-03-12     0.515791       0.325713
# 2023-03-13     0.515791       0.357102
# 2023-03-14     0.482434       0.365769
# 2023-03-15     0.499077       0.359594
#
# [4624 rows x 2 columns]
#                kospi_Close  bitcoin_Close
# kospi_Close       1.000000       0.887822
# bitcoin_Close     0.887822       1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  dollar_Close
# Date
# 1990-01-02     0.207784      0.478820
# 1990-01-03     0.207784      0.479221
# 1990-01-04     0.214471      0.437943
# 1990-01-05     0.209939      0.447161
# 1990-01-08     0.211377      0.430730
# ...                 ...           ...
# 2023-03-09     0.707088      0.681301
# 2023-03-10     0.698989      0.666212
# 2023-03-13     0.704282      0.649401
# 2023-03-14     0.683910      0.639422
# 2023-03-15     0.694074      0.660682
#
# [8484 rows x 2 columns]
#               kospi_Close  dollar_Close
# kospi_Close       1.00000      -0.21349
# dollar_Close     -0.21349       1.00000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  gold_Close
# Date
# 1990-01-02     0.207784    0.083053
# 1990-01-03     0.207784    0.079859
# 1990-01-04     0.214471    0.082337
# 1990-01-05     0.209939    0.086578
# 1990-01-08     0.211377    0.084540
# ...                 ...         ...
# 2023-03-09     0.707088    0.870683
# 2023-03-10     0.698989    0.888638
# 2023-03-13     0.704282    0.915790
# 2023-03-14     0.683910    0.912706
# 2023-03-15     0.694074    0.933194
#
# [8450 rows x 2 columns]
#              kospi_Close  gold_Close
# kospi_Close     1.000000    0.931024
# gold_Close      0.931024    1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  us_unem_Change
# Date
# 1994-10-01     0.343705        0.212389
# 1994-11-01     0.368590        0.194690
# 1994-12-01     0.349206        0.185841
# 1995-01-01     0.288545        0.194690
# 1995-02-01     0.288545        0.176991
# ...                 ...             ...
# 2023-10-22     0.979545        0.026549
# 2023-11-22     0.979545        0.026549
# 2023-12-22     0.979545        0.008850
# 2023-01-23     0.979545        0.000000
# 2023-02-23     0.979545        0.017699
#
# [341 rows x 2 columns]
#                 kospi_Close  us_unem_Change
# kospi_Close        1.000000        0.262397
# us_unem_Change     0.262397        1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  usd_krw_Close
# Date
# 2009-03-25     0.014973       0.799692
# 2009-03-26     0.021986       0.740273
# 2009-03-27     0.019001       0.771165
# 2009-03-30     0.000000       0.890027
# 2009-03-31     0.004175       0.837889
# ...                 ...            ...
# 2023-03-09     0.579590       0.726400
# 2023-03-10     0.567966       0.714296
# 2023-03-13     0.575562       0.659952
# 2023-03-14     0.546322       0.678258
# 2023-03-15     0.560911       0.697758
#
# [3646 rows x 2 columns]
#                kospi_Close  usd_krw_Close
# kospi_Close       1.000000      -0.021063
# usd_krw_Close    -0.021063       1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟
#
#
#             kospi_Close  vix_Close
# Date
# 1990-01-03     0.207784   0.123046
# 1990-01-04     0.214471   0.137050
# 1990-01-05     0.209939   0.149150
# 1990-01-08     0.211377   0.151190
# 1990-01-09     0.211625   0.177566
# ...                 ...        ...
# 2023-03-09     0.707088   0.183141
# 2023-03-10     0.698989   0.212916
# 2023-03-13     0.704282   0.236302
# 2023-03-14     0.683910   0.198368
# 2023-03-15     0.694074   0.231135
#
# [8381 rows x 2 columns]
#              kospi_Close  vix_Close
# kospi_Close     1.000000  -0.115679
# vix_Close      -0.115679   1.000000
# 🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.3-cp38-cp38-win_amd64.whl (572 kB)
#      -------------------------------------- 572.5/572.5 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels>=0.13.2 in c:\python38-64\lib\site-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: joblib>=0.11 in c:\python38-64\lib\site-packages (from pmdarima) (1.2.0)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29
#   Downloading Cython-0.29.34-py2.py3-none-any.whl (988 kB)
#      -------------------------------------- 988.1/988.1 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.2 in c:\python38-64\lib\site-packages (from pmdarima) (1.22.2)
# Requirement already satisfied: urllib3 in c:\python38-64\lib\site-packages (from pmdarima) (1.26.8)
# Requirement already satisfied: scikit-learn>=0.22 in c:\python38-64\lib\site-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\python38-64\lib\site-packages (from pmdarima) (1.10.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\python38-64\lib\site-packages (from pmdarima) (49.2.1)
# Requirement already satisfied: pandas>=0.19 in c:\python38-64\lib\site-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\python38-64\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python38-64\lib\site-packages (from pandas>=0.19->pmdarima) (2021.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python38-64\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in c:\python38-64\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\python38-64\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\python38-64\lib\site-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.8)
# Requirement already satisfied: six in c:\python38-64\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Installing collected packages: Cython, pmdarima
# Successfully installed Cython-0.29.34 pmdarima-2.0.3

# %%
import pmdarima as pm
from pmdarima.arima import ndiffs

# %%
vix.set_index('Date', inplace=True)
vix
# Out:
#             vix_Close
# Date
# 1990-01-03      18.19
# 1990-01-04      19.22
# 1990-01-05      20.11
# 1990-01-08      20.26
# 1990-01-09      22.20
# ...               ...
# 2023-03-09      22.61
# 2023-03-10      24.80
# 2023-03-13      26.52
# 2023-03-14      23.73
# 2023-03-15      26.14
#
# [8381 rows x 1 columns]

# %%
y = vix[['vix_Close']]  #.iloc[-800:]
y
# Out:
#             vix_Close
# Date
# 1990-01-03      18.19
# 1990-01-04      19.22
# 1990-01-05      20.11
# 1990-01-08      20.26
# 1990-01-09      22.20
# ...               ...
# 2023-03-09      22.61
# 2023-03-10      24.80
# 2023-03-13      26.52
# 2023-03-14      23.73
# 2023-03-15      26.14
#
# [8381 rows x 1 columns]

# %%
# 몇 차수가 필요하지? 
ndiffs(y)
# Out:
# 1

# %%
vix.plot(figsize=(10,5))
# plt.show()
# Out:
# <Axes: xlabel='Date'>

# %%
y_train = y['vix_Close'][:int(0.7*len(y))]
y_test = y['vix_Close'][int(0.7*len(y)):]

# %%
y_train
# Out:
# Date
# 1990-01-03    18.19
# 1990-01-04    19.22
# 1990-01-05    20.11
# 1990-01-08    20.26
# 1990-01-09    22.20
#               ...
# 2013-04-05    13.92
# 2013-04-08    13.19
# 2013-04-09    12.84
# 2013-04-10    12.36
# 2013-04-11    12.24
# Name: vix_Close, Length: 5866, dtype: float64

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8381 entries, 1990-01-03 to 2023-03-15
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   vix_Close  8381 non-null   float64
# dtypes: float64(1)
# memory usage: 131.0+ KB

# %%
y_train.plot()
y_test.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
kpss_diffs = ndiffs(y_train, alpha=0.05, test='kpss', max_d=6)
adf_diffs = ndiffs(y_train, alpha=0.05, test='adf', max_d=6)
n_diffs = max(adf_diffs, kpss_diffs)

print(f"d = {n_diffs}")
# Out:
# d = 1

# %%
model = pm.auto_arima(y = y_train       # 데이터
                      , d = 1           # (d)차분 차수 (기본값 = none), 지정하지 않으면 실행 기간이 매우 길어질 수 있음
                      , start_p = 0     # (p)탐색 시초값 (기본값 = 2)
                      , max_p = 3       # (기본값 = 5)
                      , start_q = 0     # (q)탐색 시초값 (기본값 = 2)
                      , max_q = 3       # (기본값 = 5)
                      , m = 1           # (기본값 = 1)
                      , seasonal = False # 기본값 = True, 계절변동 ARIMA(SARIMA)에 해당시 True로 수정
                      , stepwise = True  
                      , trace=True      # stepwise로 모델을 적합할 때마다 결과를 프린트
                      )
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=21767.631, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=21702.758, Time=0.30 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=21686.421, Time=0.28 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=21765.634, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=21581.753, Time=0.94 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=21582.567, Time=1.08 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=21582.556, Time=1.32 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=21622.545, Time=0.35 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=21648.884, Time=0.37 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=21583.318, Time=2.17 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=21579.762, Time=0.30 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=21684.425, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=21700.761, Time=0.10 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=21580.576, Time=0.42 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=21580.565, Time=0.45 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=21620.550, Time=0.18 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=21646.888, Time=0.17 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=21581.327, Time=1.12 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0]
# Total fit time: 9.901 seconds

# %% [markdown]
# ### 정상 시계열로 변환

# %% [markdown]
# https://modulabs.co.kr/blog/time-series-stationarity/

# %%
kospi.plot()

# %%
# pip install statsmodels

# %%
from statsmodels.tsa.stattools import adfuller # ADF 검정
from statsmodels.graphics.tsaplots import plot_acf

# %%
def adf_test(x):
    stat, p_value, lags, nobs, crit, icb = adfuller(x) # adfuller 함수를 이용하면 6가지 output이 나옵니다
    print('ADF statistics')
    print(stat) # ADF 검정 통계량입니다
    print('P-value')
    print(p_value) # P-value입니다

# %%
# plot_acf(kospi_transformed, lags = 30, alpha=0.05)
# plt.show()

# %%
adf_test(kospi_transformed)

# %%
# kospi.set_index('Date', inplace=True)
# kospi_transformed = np.log(kospi).diff()
# kospi_transformed.dropna(inplace=True)

# kosdaq.set_index('Date', inplace=True)
kosdaq_transformed = np.log(kosdaq).diff()
kosdaq_transformed.dropna(inplace=True)

# %%
kosdaq_transformed.plot()

# %%
# variables_transformed = []

# for i in range(len(variables)):
#     name = '{}_transformed'.format(variables[i])
#     variables[i].set_index('Date', inplace=True)
    
#     # 로그 변환 후 차분
#     name = np.log(variables[i]).diff()
#     # 차분으로 인해 생긴 데이터의 공백을 제거
#     name = variables[i].dropna()
    
#     print(name)

# %%
kospi.plot()

# %% [markdown]
# ### Data Correlation

# %%
# 날짜 다른 두 컬럼 간 상관관계 및 그래프 도출

def get_corr2(lst, standard_value):
    for i in lst:
        if str(i) != str(standard_value):
            oneone = pd.merge(standard_value, i, how = 'right', left_on = 'Date', right_on = 'Date')
            oneone = oneone.set_index('Date')
            oneone.fillna(method = 'bfill', inplace = True) 
            minmax_scaled = minmax_scaler.fit_transform(oneone.values)
            df = pd.DataFrame(data = minmax_scaled, columns = oneone.columns, index = oneone.index)
            print(df)
            print(df.corr())

            df.plot(figsize=(20,10))
            plt.title(f'{standard_value.columns[1]}_{i.columns[1]}')
            plt.show()
            print('🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟🍟')
            print('')
            print('')

# %%
get_corr(variables, kospi)

# %% [markdown]
# ### correlation over 0.7

# %%
cor_over_70 = [kospi, dow, sp500, russel2000, nasdaq, ftse, nikkie, ssec, szse, hsi, jap_bond_yield_10, 
               kor_bond_yield_1, kor_bond_yield_3, kor_bond_yield_5, kor_bond_yield_10, us_bond_yield_3, 
               us_bond_yield_5, us_bond_yield_10, brent, wti, bitcoin, gold]

'''
dow                  90.01.02 
sp500                90.01.02 
russel2000               01.01.03 
nasdaq               90.01.02 
ftse                     04.03.05
nikkie                   01.01.05 
ssec                   90.12.20 
szse                   95.01.24 
hsi                      00.12.05 
jap_bond_yield_10        06.02.07
kor_bond_yield_1       95.05.03
kor_bond_yield_3       95.05.03
kor_bond_yield_5       95.05.03
kor_bond_yield_10        00.10.26
us_bond_yield_3      90.01.08
us_bond_yield_5      90.01.08
us_bond_yield_10     90.01.08
brent                90.01.02
wti                  90.01.02
# bitcoin                  10.07.18
gold                 90.01.02

'''

# %%
for i in cor_over_70:
    print(f'{i.columns[1][:-6]}')
    get_corr(cor_over_70, i)
    print('========================================================================')
    print('========================================================================')
    print('========================================================================')

# %%
# 상관관계가 높다고 나온 feature 중, 가장 적은 기간 데이터 수집된 feature를 기준으로 concat


# 최소 기간 data 추출
df_min_len = len(cor_over_70[0])
for _ in range(len(cor_over_70)):
    if df_min_len >= len(cor_over_70[_]):
        df_min_len = len(cor_over_70[_])
        df_min = cor_over_70[_]
x = df_min

for i in cor_over_70:
    if i.columns[1] == cor_over_70[0].columns[1]:
        oneone = pd.merge(cor_over_70[0], x, how = 'right', left_on = 'Date', right_on = 'Date')
        oneone.fillna(method = 'bfill', inplace = True)
    else:
        oneone = pd.merge(i, oneone, how = 'right', left_on = 'Date', right_on = 'Date')
        oneone.fillna(method = 'bfill', inplace = True)

oneone = oneone.set_index('Date')
minmax_scaled = minmax_scaler.fit_transform(oneone.values)
df_kospi_cor = pd.DataFrame(data = minmax_scaled, columns = oneone.columns, index = oneone.index)

# %%
df_kospi_cor

# %% [markdown]
# ### SHAP

# %% [markdown]
# ## Feature Importance

# %%
import xgboost

from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split

# %%
df_kospi_cor.info()

# %%
# main.iloc[:,1:].astype(dtype='float64')

# %%
# pip install xgboost

# %%
# df 컬럼 위치 바꿔서 y값 조정

X = df_kospi_cor.iloc[:,2:]
y = df_kospi_cor['kospi_Close']

# %%
# train_test_split
# X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=34)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
model = XGBClassifier() # booster='gbtree', importance_type='gain')
model.fit(X,y)
model.feature_importances_

# %%
plt.bar(range(len(model.feature_importances_)), model.feature_importances_)
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(50,50))

axes = [ax for row_axes in axes for ax in row_axes]

xgboost.plot_importance(model, importance_type='gain', title='gain', xlabel='', grid=False, ax=axes[0])
xgboost.plot_importance(model, importance_type='cover', title='cover', xlabel='', grid=False, ax=axes[1])
xgboost.plot_importance(model, importance_type='weight', title='weight', xlabel='', grid=False, ax=axes[2])
xgboost.plot_importance(model, importance_type='total_gain', title='total_gain', xlabel='', grid=False, ax=axes[3])
xgboost.plot_importance(model, importance_type='total_cover', title='total_cover', xlabel='', grid=False, ax=axes[4])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## LSTM Permutation Feature Importance

# %% [markdown]
# ## Modeling

# %%
model = DecisionTreeClassifier(random_state = 42)

# %%
model.fit(x_train, y_train)
